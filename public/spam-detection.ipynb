# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import nltk
import string
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import svm
from sklearn.model_selection import GridSearchCV
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
import common

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/saravanadev/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/saravanadev/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_csv('datasets/spam_ham_dataset.csv')
df
# Out:
#       Unnamed: 0 label                                               text  \
# 0            605   ham  Subject: enron methanol ; meter # : 988291\r\n...
# 1           2349   ham  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2           3624   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3           4685  spam  Subject: photoshop , windows , office . cheap ...
# 4           2030   ham  Subject: re : indian springs\r\nthis deal is t...
# ...          ...   ...                                                ...
# 5166        1518   ham  Subject: put the 10 on the ft\r\nthe transport...
# 5167         404   ham  Subject: 3 / 4 / 2000 and following noms\r\nhp...
# 5168        2933   ham  Subject: calpine daily gas nomination\r\n>\r\n...
# 5169        1409   ham  Subject: industrial worksheets for august 2000...
# 5170        4807  spam  Subject: important online banking alert\r\ndea...
#
#       label_num
# 0             0
# 1             0
# 2             0
# 3             1
# 4             0
# ...         ...
# 5166          0
# 5167          0
# 5168          0
# 5169          0
# 5170          1
#
# [5171 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5171 entries, 0 to 5170
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5171 non-null   int64
#  1   label       5171 non-null   object
#  2   text        5171 non-null   object
#  3   label_num   5171 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 161.7+ KB

# %%
encoder = LabelEncoder()
df['Label'] = encoder.fit_transform(df['label'])

df = df.drop_duplicates(keep='first')

# %%
df
# Out:
#       Unnamed: 0 label                                               text  \
# 0            605   ham  Subject: enron methanol ; meter # : 988291\r\n...
# 1           2349   ham  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2           3624   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3           4685  spam  Subject: photoshop , windows , office . cheap ...
# 4           2030   ham  Subject: re : indian springs\r\nthis deal is t...
# ...          ...   ...                                                ...
# 5166        1518   ham  Subject: put the 10 on the ft\r\nthe transport...
# 5167         404   ham  Subject: 3 / 4 / 2000 and following noms\r\nhp...
# 5168        2933   ham  Subject: calpine daily gas nomination\r\n>\r\n...
# 5169        1409   ham  Subject: industrial worksheets for august 2000...
# 5170        4807  spam  Subject: important online banking alert\r\ndea...
#
#       label_num  Label
# 0             0      0
# 1             0      0
# 2             0      0
# 3             1      1
# 4             0      0
# ...         ...    ...
# 5166          0      0
# 5167          0      0
# 5168          0      0
# 5169          0      0
# 5170          1      1
#
# [5171 rows x 5 columns]

# %%
ps = PorterStemmer()

# %%
df['imp_feature'] = df['text'].apply(common.getImportantFeatures)
df
# Out:
#       Unnamed: 0 label                                               text  \
# 0            605   ham  Subject: enron methanol ; meter # : 988291\r\n...
# 1           2349   ham  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2           3624   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3           4685  spam  Subject: photoshop , windows , office . cheap ...
# 4           2030   ham  Subject: re : indian springs\r\nthis deal is t...
# ...          ...   ...                                                ...
# 5166        1518   ham  Subject: put the 10 on the ft\r\nthe transport...
# 5167         404   ham  Subject: 3 / 4 / 2000 and following noms\r\nhp...
# 5168        2933   ham  Subject: calpine daily gas nomination\r\n>\r\n...
# 5169        1409   ham  Subject: industrial worksheets for august 2000...
# 5170        4807  spam  Subject: important online banking alert\r\ndea...
#
#       label_num  Label                                        imp_feature
# 0             0      0  [subject, enron, methanol, meter, 988291, this...
# 1             0      0  [subject, hpl, nom, for, january, 9, 2001, see...
# 2             0      0  [subject, neon, retreat, ho, ho, ho, we, re, a...
# 3             1      1  [subject, photoshop, windows, office, cheap, m...
# 4             0      0  [subject, re, indian, springs, this, deal, is,...
# ...         ...    ...                                                ...
# 5166          0      0  [subject, put, the, 10, on, the, ft, the, tran...
# 5167          0      0  [subject, 3, 4, 2000, and, following, noms, hp...
# 5168          0      0  [subject, calpine, daily, gas, nomination, jul...
# 5169          0      0  [subject, industrial, worksheets, for, august,...
# 5170          1      1  [subject, important, online, banking, alert, d...
#
# [5171 rows x 6 columns]

# %%
df['imp_feature'] = df['imp_feature'].apply(common.stopWordRemoval)
df
# Out:
#       Unnamed: 0 label                                               text  \
# 0            605   ham  Subject: enron methanol ; meter # : 988291\r\n...
# 1           2349   ham  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2           3624   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3           4685  spam  Subject: photoshop , windows , office . cheap ...
# 4           2030   ham  Subject: re : indian springs\r\nthis deal is t...
# ...          ...   ...                                                ...
# 5166        1518   ham  Subject: put the 10 on the ft\r\nthe transport...
# 5167         404   ham  Subject: 3 / 4 / 2000 and following noms\r\nhp...
# 5168        2933   ham  Subject: calpine daily gas nomination\r\n>\r\n...
# 5169        1409   ham  Subject: industrial worksheets for august 2000...
# 5170        4807  spam  Subject: important online banking alert\r\ndea...
#
#       label_num  Label                                        imp_feature
# 0             0      0  [subject, enron, methanol, meter, 988291, foll...
# 1             0      0  [subject, hpl, nom, january, 9, 2001, see, att...
# 2             0      0  [subject, neon, retreat, ho, ho, ho, around, w...
# 3             1      1  [subject, photoshop, windows, office, cheap, m...
# 4             0      0  [subject, indian, springs, deal, book, teco, p...
# ...         ...    ...                                                ...
# 5166          0      0  [subject, put, 10, ft, transport, volumes, dec...
# 5167          0      0  [subject, 3, 4, 2000, following, noms, hpl, ta...
# 5168          0      0  [subject, calpine, daily, gas, nomination, jul...
# 5169          0      0  [subject, industrial, worksheets, august, 2000...
# 5170          1      1  [subject, important, online, banking, alert, d...
#
# [5171 rows x 6 columns]

# %%
ps = PorterStemmer()
df['imp_feature'] = df['imp_feature'].apply(common.stem)
df
# Out:
#       Unnamed: 0 label                                               text  \
# 0            605   ham  Subject: enron methanol ; meter # : 988291\r\n...
# 1           2349   ham  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2           3624   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3           4685  spam  Subject: photoshop , windows , office . cheap ...
# 4           2030   ham  Subject: re : indian springs\r\nthis deal is t...
# ...          ...   ...                                                ...
# 5166        1518   ham  Subject: put the 10 on the ft\r\nthe transport...
# 5167         404   ham  Subject: 3 / 4 / 2000 and following noms\r\nhp...
# 5168        2933   ham  Subject: calpine daily gas nomination\r\n>\r\n...
# 5169        1409   ham  Subject: industrial worksheets for august 2000...
# 5170        4807  spam  Subject: important online banking alert\r\ndea...
#
#       label_num  Label                                        imp_feature
# 0             0      0  subject enron methanol meter 988291 follow not...
# 1             0      0  subject hpl nom januari 9 2001 see attach file...
# 2             0      0  subject neon retreat ho ho ho around wonder ti...
# 3             1      1  subject photoshop window offic cheap main tren...
# 4             0      0  subject indian spring deal book teco pvr reven...
# ...         ...    ...                                                ...
# 5166          0      0  subject put 10 ft transport volum decreas 2500...
# 5167          0      0  subject 3 4 2000 follow nom hpl take extra 15 ...
# 5168          0      0  subject calpin daili ga nomin juli mention ear...
# 5169          0      0  subject industri worksheet august 2000 activ a...
# 5170          1      1  subject import onlin bank alert dear valu citi...
#
# [5171 rows x 6 columns]

# %%
X = df['imp_feature']
y = df['Label']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
tfidf = TfidfVectorizer()
feature = tfidf.fit_transform(X_train)

params = {'kernel':['linear','rbf'],'gamma':[1e-3,1e-4], 'C':[1,10,100,1000]}
 
model = GridSearchCV(svm.SVC(),params)
model.fit(feature, y_train)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001],
#                          'kernel': ['linear', 'rbf']})

# %%
y_predict = tfidf.transform(X_test)
print("Accuracy:",model.score(y_predict,y_test)*100)
 
import joblib
joblib.dump(model, 'classifier.pkl')
joblib.dump(tfidf, 'vectorizer.pkl')
# Out:
# Accuracy: 99.07192575406032
# ['vectorizer.pkl']

# %%
msg = "the second option would be to stay here in houston , have dinner together at a nice restaurant , and then have dessert and a time for visiting and recharging at one of our homes on that saturday evening"

# %%
arg1 = pd.DataFrame([msg])
arg1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1 non-null      object
# dtypes: object(1)
# memory usage: 136.0+ bytes

# %%
import os
clf = joblib.load(os.path.join(os.path.dirname(os.path.abspath('')),'email-spam/classifier.pkl'))
vectorizer = joblib.load(os.path.join(os.path.dirname(os.path.abspath('')),'email-spam/vectorizer.pkl'))


message = arg1[0].apply(common.getImportantFeatures)
message = message.apply(common.stopWordRemoval)
message = message.apply(common.stem)
res = vectorizer.transform(message)


res = clf.predict(res)[0]
print(res)
# Out:
# 0
